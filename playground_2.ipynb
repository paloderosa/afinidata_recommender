# %%
import os

from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

from recommender.read_db import ReadDatabase
from recommender.preprocess import SetUpDataframes
from recommender.models import CollaborativeFiltering
from recommender.datasets import Datasets

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlib inline

# %%
#dotenv_path = os.path.join(os.path.dirname(__file__), '.env')
load_dotenv('.env')

DB_URI = os.environ.get("DB_URI")
engine = create_engine(DB_URI)

reader = ReadDatabase(engine, 'CM_BD')

feedback_df = reader.get_data('user_id, post_id, value, created_at', 'posts_feedback', None)
#feedback_df = feedback_df[feedback_df['created_at']>pd.to_datetime('2019-10-01')]
feedback_matrix = SetUpDataframes.feedback_matrix(feedback_df)
# Out:
# ----------------------------------------------------------------------
# reading columns user_id, post_id, value, created_at from table posts_feedback from database CM_BD

# %%
datasets = Datasets(feedback_matrix)

# %%
datasets.

# %%
train, test = datasets.train_test_split(0.30)

# %%
model = CollaborativeFiltering(n_posts=len(datasets.posts), n_users=len(datasets.users), n_features=5)

# %%
model.train(train, test, 2000, 0, 0.001)
# Out:
# Epoch 0 / train loss 411674.024 / test loss 177215.297
# Epoch 1 / train loss 411673.730 / test loss 177215.176
# Epoch 2 / train loss 411673.357 / test loss 177215.031
# Epoch 3 / train loss 411672.857 / test loss 177214.845
# Epoch 4 / train loss 411672.165 / test loss 177214.600
# Epoch 5 / train loss 411671.186 / test loss 177214.268
# Epoch 6 / train loss 411669.789 / test loss 177213.810
# Epoch 7 / train loss 411667.777 / test loss 177213.171
# Epoch 8 / train loss 411664.865 / test loss 177212.270
# Epoch 9 / train loss 411660.634 / test loss 177210.993
# Epoch 10 / train loss 411654.467 / test loss 177209.169
# Epoch 11 / train loss 411645.457 / test loss 177206.553
# Epoch 12 / train loss 411632.264 / test loss 177202.785
# Epoch 13 / train loss 411612.917 / test loss 177197.338
# Epoch 14 / train loss 411584.503 / test loss 177189.442
# Epoch 15 / train loss 411542.734 / test loss 177177.964
# Epoch 16 / train loss 411481.287 / test loss 177161.248
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 0.001, 0.001)
# Out:
# Epoch 0 / train loss 411674.015 / test loss 177215.293
# Epoch 1 / train loss 411673.718 / test loss 177215.172
# Epoch 2 / train loss 411673.341 / test loss 177215.025
# Epoch 3 / train loss 411672.835 / test loss 177214.838
# Epoch 4 / train loss 411672.135 / test loss 177214.591
# Epoch 5 / train loss 411671.146 / test loss 177214.255
# Epoch 6 / train loss 411669.734 / test loss 177213.793
# Epoch 7 / train loss 411667.700 / test loss 177213.148
# Epoch 8 / train loss 411664.759 / test loss 177212.238
# Epoch 9 / train loss 411660.485 / test loss 177210.948
# Epoch 10 / train loss 411654.257 / test loss 177209.107
# Epoch 11 / train loss 411645.159 / test loss 177206.466
# Epoch 12 / train loss 411631.839 / test loss 177202.661
# Epoch 13 / train loss 411612.307 / test loss 177197.161
# Epoch 14 / train loss 411583.625 / test loss 177189.188
# Epoch 15 / train loss 411541.466 / test loss 177177.599
# Epoch 16 / train loss 411479.450 / test loss 177160.722
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 0.01, 0.001)
# Out:
# Epoch 0 / train loss 411674.035 / test loss 177215.301
# Epoch 1 / train loss 411673.741 / test loss 177215.180
# Epoch 2 / train loss 411673.372 / test loss 177215.035
# Epoch 3 / train loss 411672.878 / test loss 177214.851
# Epoch 4 / train loss 411672.195 / test loss 177214.608
# Epoch 5 / train loss 411671.232 / test loss 177214.279
# Epoch 6 / train loss 411669.856 / test loss 177213.827
# Epoch 7 / train loss 411667.876 / test loss 177213.197
# Epoch 8 / train loss 411665.013 / test loss 177212.310
# Epoch 9 / train loss 411660.855 / test loss 177211.053
# Epoch 10 / train loss 411654.796 / test loss 177209.260
# Epoch 11 / train loss 411645.947 / test loss 177206.690
# Epoch 12 / train loss 411632.993 / test loss 177202.989
# Epoch 13 / train loss 411614.000 / test loss 177197.641
# Epoch 14 / train loss 411586.113 / test loss 177189.891
# Epoch 15 / train loss 411545.124 / test loss 177178.628
# Epoch 16 / train loss 411484.833 / test loss 177162.229
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 0.1, 0.001)
# Out:
# Epoch 0 / train loss 411674.021 / test loss 177215.295
# Epoch 1 / train loss 411673.725 / test loss 177215.174
# Epoch 2 / train loss 411673.350 / test loss 177215.027
# Epoch 3 / train loss 411672.848 / test loss 177214.841
# Epoch 4 / train loss 411672.153 / test loss 177214.594
# Epoch 5 / train loss 411671.173 / test loss 177214.261
# Epoch 6 / train loss 411669.773 / test loss 177213.802
# Epoch 7 / train loss 411667.760 / test loss 177213.162
# Epoch 8 / train loss 411664.850 / test loss 177212.261
# Epoch 9 / train loss 411660.624 / test loss 177210.983
# Epoch 10 / train loss 411654.468 / test loss 177209.161
# Epoch 11 / train loss 411645.478 / test loss 177206.549
# Epoch 12 / train loss 411632.323 / test loss 177202.789
# Epoch 13 / train loss 411613.039 / test loss 177197.355
# Epoch 14 / train loss 411584.732 / test loss 177189.481
# Epoch 15 / train loss 411543.134 / test loss 177178.041
# Epoch 16 / train loss 411481.961 / test loss 177161.387
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 1, 0.001)
# Out:
# Epoch 0 / train loss 411674.035 / test loss 177215.295
# Epoch 1 / train loss 411673.743 / test loss 177215.176
# Epoch 2 / train loss 411673.375 / test loss 177215.032
# Epoch 3 / train loss 411672.882 / test loss 177214.849
# Epoch 4 / train loss 411672.199 / test loss 177214.607
# Epoch 5 / train loss 411671.235 / test loss 177214.279
# Epoch 6 / train loss 411669.860 / test loss 177213.828
# Epoch 7 / train loss 411667.884 / test loss 177213.199
# Epoch 8 / train loss 411665.027 / test loss 177212.315
# Epoch 9 / train loss 411660.882 / test loss 177211.061
# Epoch 10 / train loss 411654.849 / test loss 177209.274
# Epoch 11 / train loss 411646.046 / test loss 177206.714
# Epoch 12 / train loss 411633.175 / test loss 177203.030
# Epoch 13 / train loss 411614.326 / test loss 177197.713
# Epoch 14 / train loss 411586.686 / test loss 177190.014
# Epoch 15 / train loss 411546.113 / test loss 177178.838
# Epoch 16 / train loss 411486.515 / test loss 177162.585
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 10, 0.001)
# Out:
# Epoch 0 / train loss 411674.193 / test loss 177215.300
# Epoch 1 / train loss 411673.922 / test loss 177215.186
# Epoch 2 / train loss 411673.592 / test loss 177215.054
# Epoch 3 / train loss 411673.163 / test loss 177214.888
# Epoch 4 / train loss 411672.581 / test loss 177214.674
# Epoch 5 / train loss 411671.775 / test loss 177214.388
# Epoch 6 / train loss 411670.642 / test loss 177214.001
# Epoch 7 / train loss 411669.039 / test loss 177213.470
# Epoch 8 / train loss 411666.755 / test loss 177212.732
# Epoch 9 / train loss 411663.488 / test loss 177211.702
# Epoch 10 / train loss 411658.800 / test loss 177210.253
# Epoch 11 / train loss 411652.059 / test loss 177208.208
# Epoch 12 / train loss 411642.344 / test loss 177205.307
# Epoch 13 / train loss 411628.320 / test loss 177201.178
# Epoch 14 / train loss 411608.051 / test loss 177195.285
# Epoch 15 / train loss 411578.724 / test loss 177186.853
# Epoch 16 / train loss 411536.260 / test loss 177174.765
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 100, 0.001)
# Out:
# Epoch 0 / train loss 411675.446 / test loss 177215.322
# Epoch 1 / train loss 411675.130 / test loss 177215.265
# Epoch 2 / train loss 411674.886 / test loss 177215.218
# Epoch 3 / train loss 411674.682 / test loss 177215.174
# Epoch 4 / train loss 411674.498 / test loss 177215.126
# Epoch 5 / train loss 411674.319 / test loss 177215.072
# Epoch 6 / train loss 411674.135 / test loss 177215.008
# Epoch 7 / train loss 411673.935 / test loss 177214.931
# Epoch 8 / train loss 411673.710 / test loss 177214.836
# Epoch 9 / train loss 411673.446 / test loss 177214.719
# Epoch 10 / train loss 411673.132 / test loss 177214.574
# Epoch 11 / train loss 411672.753 / test loss 177214.396
# Epoch 12 / train loss 411672.289 / test loss 177214.175
# Epoch 13 / train loss 411671.718 / test loss 177213.901
# Epoch 14 / train loss 411671.012 / test loss 177213.561
# Epoch 15 / train loss 411670.137 / test loss 177213.140
# Epoch 16 / train loss 411669.050 / test loss 177212.618
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()

# %%
model.train(train, test, 2000, 1000, 0.001)
# Out:
# Epoch 0 / train loss 411674.620 / test loss 177215.498
# Epoch 1 / train loss 411674.504 / test loss 177215.500
# Epoch 2 / train loss 411674.500 / test loss 177215.500
# Epoch 3 / train loss 411674.500 / test loss 177215.500
# Epoch 4 / train loss 411674.500 / test loss 177215.500
# Epoch 5 / train loss 411674.500 / test loss 177215.500
# Epoch 6 / train loss 411674.500 / test loss 177215.500
# Epoch 7 / train loss 411674.500 / test loss 177215.500
# Epoch 8 / train loss 411674.500 / test loss 177215.500
# Epoch 9 / train loss 411674.500 / test loss 177215.500
# Epoch 10 / train loss 411674.500 / test loss 177215.500
# Epoch 11 / train loss 411674.500 / test loss 177215.500
# Epoch 12 / train loss 411674.500 / test loss 177215.500
# Epoch 13 / train loss 411674.500 / test loss 177215.500
# Epoch 14 / train loss 411674.500 / test loss 177215.500
# Epoch 15 / train loss 411674.500 / test loss 177215.500
# Epoch 16 / train loss 411674.500 / test loss 177215.500
# ...

# %%
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x=np.arange(len(model.training_losses)), y=model.training_losses, label='train losses')
sns.scatterplot(x=np.arange(len(model.test_losses)), y=model.test_losses, label='test losses')
plt.legend()
